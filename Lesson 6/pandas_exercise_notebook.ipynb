# %%
import pandas as pd

# %% [markdown]
# ## Part 1 exercise
# 1. Load the wine dataset
# 1. How many rows are there?
# 1. What columns are there?
# 1. What are the minimum and maximum values of the `total_sulfur_dioxide` column?
# 1. What is the mean of the `pH` column?
# 1. Which columns are non-numerical?
# 1. How many missing values do you see?
#
# #### &#x1F4A1; Tip &#x1F4A1;
# * Does `read_csv()` read the columns correctly?
# * Employ the appropriate parameter (what value should be sent?)

# %%
wine = pd.read_csv("wine_dataset.txt", sep=";")

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'style'],
#       dtype='object')

# %%
wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  style                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# style                    object
# dtype: object

# %%
wine.isna().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# style                   0
# dtype: int64

# %% [markdown]
# 1. pH < 3.3 and sulfates > 0.6
#     1. Extract wines with pH below 3.3 and sulfates above 0.6 using `query`
#     1. Repeat, this time with boolean indexing
#     1. **Challenge** use boolean indexing to achieve this but **without** and, or etc.

# %% [markdown]
# ## Part 2 exrecise
# 1. pH < 3.3 and sulfates > 0.6
#     1. Extract wines with pH below 3.3 and sulfates above 0.6 using `query`
#     1. Repeat, this time with boolean indexing
#     1. **Challenge** use boolean indexing to achieve thes same result, but **without using** "and", "or" etc.

# %%
df = pd.read_csv('wine_dataset.txt', sep=';')

# %%
# Q 1A
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 15              8.9              0.62         0.19             3.9      0.170
# ...             ...               ...          ...             ...        ...
# 6417            6.0              0.27         0.40             1.7      0.021
# 6418            5.7              0.40         0.35             5.1      0.026
# 6426            6.7              0.22         0.33             1.2      0.036
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
#
# ...

# %%
print(df.columns)
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'style'],
#       dtype='object')

# %%
# answer:
df[(df['pH'] < 3.3) & (df['sulphates'] > 0.6)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 1               7.8              0.88         0.00             2.6      0.098  \
# 2               7.8              0.76         0.04             2.3      0.092
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 15              8.9              0.62         0.19             3.9      0.170
# ...             ...               ...          ...             ...        ...
# 6417            6.0              0.27         0.40             1.7      0.021
# 6418            5.7              0.40         0.35             5.1      0.026
# 6426            6.7              0.22         0.33             1.2      0.036
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
#
# ...

# %%
# Q 1B
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 15              8.9              0.62         0.19             3.9      0.170
# ...             ...               ...          ...             ...        ...
# 6417            6.0              0.27         0.40             1.7      0.021
# 6418            5.7              0.40         0.35             5.1      0.026
# 6426            6.7              0.22         0.33             1.2      0.036
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
#
# ...

# %%
df.query("pH < 3.3 and sulphates > 0.6")
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 1               7.8              0.88         0.00             2.6      0.098  \
# 2               7.8              0.76         0.04             2.3      0.092
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 15              8.9              0.62         0.19             3.9      0.170
# ...             ...               ...          ...             ...        ...
# 6417            6.0              0.27         0.40             1.7      0.021
# 6418            5.7              0.40         0.35             5.1      0.026
# 6426            6.7              0.22         0.33             1.2      0.036
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
#
# ...

# %%
# Q 1C
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 15              8.9              0.62         0.19             3.9      0.170
# ...             ...               ...          ...             ...        ...
# 6417            6.0              0.27         0.40             1.7      0.021
# 6418            5.7              0.40         0.35             5.1      0.026
# 6426            6.7              0.22         0.33             1.2      0.036
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
#
# ...

# %% [markdown]
# 2. Wines by quality level
#     1. How many wines are there *of each quality level* with chlorides <= 0.03?
#     1. How many wines are there *of each quality level* with chlorides >= 0.07?
#     1. Is there anything to learn from the comparison about the relation between chlorides and quality?
#
# **Tip 1**: use `.sort_index()` to see the count by order of values.
#
# **Tip 2** (for C): add `normalize=True` as an argument to `value_counts`

# %%
# Q 2A
# Out:
# 3      2
# 4      9
# 5     72
# 6    241
# 7    192
# 8     48
# 9      2
# Name: quality, dtype: int64

# %%
# Q 2B
# Out:
# 3     11
# 4     48
# 5    692
# 6    553
# 7    119
# 8     13
# Name: quality, dtype: int64

# %%
# Q 2C
# Out:
# 3     0.353357
# 4     1.590106
# 5    12.720848
# 6    42.579505
# 7    33.922261
# 8     8.480565
# 9     0.353357
# Name: quality, dtype: float64

# %%
# Q 2C
# Out:
# 3     0.766017
# 4     3.342618
# 5    48.189415
# 6    38.509749
# 7     8.286908
# 8     0.905292
# Name: quality, dtype: float64

# %% [markdown]
# 3. Extract all rows where `free_sulfur_dioxide` is between 98 and 108 using logical indexing:
#     1. Using `&` (and)
#     1. **Challenge** using `Series.between(a, b)` (Refer to the [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.between.html)  if needed )
#
# 1. A dataframe for white wine
#     1. create a dataframe called `white` that has just wines of type "white".
#     1. **Challenge:** explain why the expression `wine.style=='white'` does not produce the expected result.
# 1. Using the dataframe `white`, extract all rows where quality is either 3 or 9
#     1. Using logical indexing with `|` (or)
#     1. **Challenge:** using `.isin` ([doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.isin.html))
# 1. Sort the previous result by quality

# %%
# Q 3A
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 5060            6.7              0.24         0.30            3.85      0.042
# 5069            6.7              0.24         0.30            3.85      0.042
# 5119            6.0              0.23         0.15            9.70      0.048
# 5122            6.0              0.23         0.15            9.70      0.048
# 5219            6.3              0.20         0.26            4.70      0.040
# 5460            6.2              0.22         0.30           12.40      0.054
# 5461            6.5              0.27         0.19            6.60      0.045
# 5462            6.5              0.27         0.19            6.60      0.045
# 5468            6.2              0.22         0.30           12.40      0.054
# 5470            6.5              0.27         0.19            6.60      0.045
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
df[(df['free_sulfur_dioxide'] > 97) & (df['free_sulfur_dioxide'] < 109)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 5060            6.7              0.24         0.30            3.85      0.042  \
# 5069            6.7              0.24         0.30            3.85      0.042
# 5119            6.0              0.23         0.15            9.70      0.048
# 5122            6.0              0.23         0.15            9.70      0.048
# 5219            6.3              0.20         0.26            4.70      0.040
# 5460            6.2              0.22         0.30           12.40      0.054
# 5461            6.5              0.27         0.19            6.60      0.045
# 5462            6.5              0.27         0.19            6.60      0.045
# 5468            6.2              0.22         0.30           12.40      0.054
# 5470            6.5              0.27         0.19            6.60      0.045
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates
# ...

# %%
df[df['free_sulfur_dioxide'].between(98, 108)]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 5060            6.7              0.24         0.30            3.85      0.042  \
# 5069            6.7              0.24         0.30            3.85      0.042
# 5119            6.0              0.23         0.15            9.70      0.048
# 5122            6.0              0.23         0.15            9.70      0.048
# 5219            6.3              0.20         0.26            4.70      0.040
# 5460            6.2              0.22         0.30           12.40      0.054
# 5461            6.5              0.27         0.19            6.60      0.045
# 5462            6.5              0.27         0.19            6.60      0.045
# 5468            6.2              0.22         0.30           12.40      0.054
# 5470            6.5              0.27         0.19            6.60      0.045
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates
# ...

# %%
# Q 3B
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 5060            6.7              0.24         0.30            3.85      0.042
# 5069            6.7              0.24         0.30            3.85      0.042
# 5119            6.0              0.23         0.15            9.70      0.048
# 5122            6.0              0.23         0.15            9.70      0.048
# 5219            6.3              0.20         0.26            4.70      0.040
# 5460            6.2              0.22         0.30           12.40      0.054
# 5461            6.5              0.27         0.19            6.60      0.045
# 5462            6.5              0.27         0.19            6.60      0.045
# 5468            6.2              0.22         0.30           12.40      0.054
# 5470            6.5              0.27         0.19            6.60      0.045
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
# Q 4
white = df[df['style'] == 'white']

# %%
white
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 1599            7.0              0.27         0.36            20.7      0.045  \
# 1600            6.3              0.30         0.34             1.6      0.049
# 1601            8.1              0.28         0.40             6.9      0.050
# 1602            7.2              0.23         0.32             8.5      0.058
# 1603            7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.style == 'white'
# Out:
# False

# %%
white = df[df['style'] != 'white']
white
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 0               7.4             0.700         0.00             1.9      0.076  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Q 5A
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1850            8.5             0.260         0.21           16.20      0.074
# 1852            5.8             0.240         0.44            3.50      0.029
# 1893            9.1             0.590         0.38            1.60      0.066
# 2044            7.1             0.320         0.32           11.00      0.038
# 2339            6.9             0.390         0.40            4.60      0.022
# 2373            9.1             0.270         0.45           10.60      0.035
# 2419            6.6             0.360         0.29            1.60      0.021
# 2426            7.4             0.240         0.36            2.00      0.031
# 2472           10.3             0.170         0.47            1.40      0.037
# 2475            6.9             0.360         0.34            4.20      0.018
# 2633            7.9             0.640         0.46           10.60      0.244
# ...

# %%
# Q 5B
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1850            8.5             0.260         0.21           16.20      0.074
# 1852            5.8             0.240         0.44            3.50      0.029
# 1893            9.1             0.590         0.38            1.60      0.066
# 2044            7.1             0.320         0.32           11.00      0.038
# 2339            6.9             0.390         0.40            4.60      0.022
# 2373            9.1             0.270         0.45           10.60      0.035
# 2419            6.6             0.360         0.29            1.60      0.021
# 2426            7.4             0.240         0.36            2.00      0.031
# 2472           10.3             0.170         0.47            1.40      0.037
# 2475            6.9             0.360         0.34            4.20      0.018
# 2633            7.9             0.640         0.46           10.60      0.244
# ...

# %%
# 6
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1850            8.5             0.260         0.21           16.20      0.074
# 5008            6.2             0.230         0.35            0.70      0.051
# 4906            9.4             0.240         0.29            8.50      0.037
# 4864            4.2             0.215         0.23            5.10      0.041
# 4686            6.1             0.200         0.34            9.50      0.041
# 3972            7.6             0.480         0.37            1.20      0.034
# 3649           11.8             0.230         0.38           11.10      0.034
# 3530            7.1             0.490         0.22            2.00      0.047
# 3287            6.7             0.250         0.26            1.55      0.041
# 3083            7.5             0.320         0.24            4.60      0.053
# 5409            6.8             0.260         0.34           15.10      0.060
# ...

# %% [markdown]
# 7. Extract multiple row/ column by index/name:
#     1. Retrieve rows 22, 44, 55
#     1. For the same rows, retrieve just the wine style and density
#     1. **Challenge**: Retrieve just the wine style and density for every 50th rows
#
# **Tip 1**: lists are valid arguments to `loc`
#
# **Tip 2 (for 6c)**: how would you extract every 50th row from a `list`?
#
#
# 8. Sorting
#     1. Display the five wines with lowest `residual_sugar`, sorted ascending
#     1. Display the five wines with highest `density`, sorted descending
#     1. Display the five wines with **highest** `density`, sorted **ascending**
#     1. Display just the `alcohol` values for the five wines with highest density
#
# **Tip 3 (for 7b):** Use `.head()` to get the *first* 5 lines of a dataframe
#
# **Tip 4 (for 7c):** Use `.tail()` to get the *last* 5 lines of a dataframe

# %%
# Q 7A
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 22            7.9              0.43         0.21             1.6      0.106
# 44            6.8              0.67         0.02             1.8      0.050
# 55            7.7              0.62         0.04             3.8      0.084
#
#     free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 44                  5.0                  11.0   0.9962  3.48       0.52
# 55                 25.0                  45.0   0.9978  3.34       0.53
#
#     alcohol  quality style
# 22      9.5        5   red
# 44      9.5        5   red
# 55      9.5        5   red

# %%
# Q 7B
# Out:
#    style  density
# 22   red   0.9966
# 44   red   0.9962
# 55   red   0.9978

# %%
# Out:
#       style  density
# 0       red  0.99780
# 50      red  0.99710
# 100     red  0.99720
# 150     red  0.99580
# 200     red  0.99695
# ...     ...      ...
# 6250  white  0.98966
# 6300  white  0.99480
# 6350  white  0.99472
# 6400  white  0.99142
# 6450  white  0.99488
#
# [130 rows x 2 columns]

# %%
# Q 8A
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3644            8.7              0.24         0.35             0.6      0.042
# 3638            8.7              0.24         0.35             0.6      0.042
# 6281            6.8              0.32         0.33             0.7      0.027
# 5008            6.2              0.23         0.35             0.7      0.051
# 4186            5.1              0.14         0.25             0.7      0.039
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 3644                 11.0                  71.0   0.9926  3.08       0.38
# 3638                 11.0                  71.0   0.9926  3.08       0.38
# 6281                 15.0                  66.0   0.9899  3.11       0.31
# 5008                 24.0                 111.0   0.9916  3.37       0.43
# 4186                 15.0                  89.0   0.9919  3.22       0.43
#
#       alcohol  quality  style
# ...

# %%
# Q 8B
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4380            7.8             0.965         0.60            65.8      0.074
# 3262            7.9             0.330         0.28            31.6      0.053
# 3252            7.9             0.330         0.28            31.6      0.053
# 1435           10.2             0.540         0.37            15.4      0.214
# 1434           10.2             0.540         0.37            15.4      0.214
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4380                  8.0                 160.0  1.03898  3.39       0.69
# 3262                 35.0                 176.0  1.01030  3.15       0.38
# 3252                 35.0                 176.0  1.01030  3.15       0.38
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 1434                 55.0                  95.0  1.00369  3.18       0.77
#
#       alcohol  quality  style
# ...

# %%
# Q 8C
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1435           10.2             0.540         0.37            15.4      0.214
# 1434           10.2             0.540         0.37            15.4      0.214
# 3252            7.9             0.330         0.28            31.6      0.053
# 3262            7.9             0.330         0.28            31.6      0.053
# 4380            7.8             0.965         0.60            65.8      0.074
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 3252                 35.0                 176.0  1.01030  3.15       0.38
# 3262                 35.0                 176.0  1.01030  3.15       0.38
# 4380                  8.0                 160.0  1.03898  3.39       0.69
#
#       alcohol  quality  style
# ...

# %%
# Q 8D
# Out:
# 4380    11.7
# 3262     8.8
# 3252     8.8
# 1435     9.0
# 1434     9.0
# Name: alcohol, dtype: float64

# %%
fruits = ['apple', 'orange', 'apple']
# output: {'apple':2, 'orange':1}

output = {}
for fruit in fruits:
    if fruit not in output:
        output[fruit] = 1
    else:
        output[fruit] += 1

# %%
output
# Out:
# {'apple': 2, 'orange': 1}
